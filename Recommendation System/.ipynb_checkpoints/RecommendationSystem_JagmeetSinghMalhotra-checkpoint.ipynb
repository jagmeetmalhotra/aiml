# %% [markdown]
# # DOMAIN:  Smartphone, Electronics
# ## •CONTEXT: India is the second largest market globally for smartphones after China. About 134 million smartphones were sold across India in the year 2017 and is estimated to increase to about 442 million in 2022. India ranked second in the average time spent on mobile web by smartphone  users  across  Asia  Pacific.  The  combination  of  very  high  sales  volumes  and  the  average  smartphone  consumer  behaviour  has made India a very attractive market for foreign vendors. As per Consumer behaviour, 97% of consumers turn to a search engine when they are buying a product vs. 15% who turn to social media. If a seller succeeds to publish smartphones based on user’s behaviour/choice at the right  place,  there  are  90%  chances  that  user  will  enquire  for  the  same.  This  Case  Study  is  targeted  to  build  a  recommendation  system based on individual consumer’s behaviour or choice.
#
# ## •DATA DESCRIPTION:
# ### •author : name of the person who gave the rating
# ### •country : country the person who gave the rating belongs to
# ### •data : date of the rating
# ### •domain: website from which the rating was taken from
# ### •extract: rating content
# ### •language: language in which the rating was given
# ### •product: name of the product/mobile phone for which the rating was given
# ### •score: average rating for the phone
# ### •score_max: highest rating given for the phone
# ### •source: source from where the rating was taken
#
# ## •PROJECT  OBJECTIVE: We  will  build  a  recommendation  system  using  popularity  based  and  collaborative filtering methods to recommend mobile phones to a user which are most popular and personalised respectively

# %% [markdown]
# ### Steps and tasks: [ Total Score: 60 points]
# ### 1.Import the necessary libraries and read the provided CSVs as a data frame and perform the below steps. [15 Marks]
#
# #### A. Merge all the provided CSVs into one dataFrame. [2 Marks]
# #### B. Explore, understand the Data and share at least 2 observations. [2 Marks]
# #### C. Round off scores to the nearest integers. [3 Marks]
# #### D. Check for missing values. Impute the missing values, if any. [2 Marks]
# #### E. Check for duplicate values and remove them, if any. [2 Marks]
# #### F.  Keep only 1 Million data samples. Use random state=612. [2 Marks]
# #### G. Drop irrelevant features. Keep features like Author, Product, and Score. [2 Marks]

# %%
# Load required packages
import pandas as pd
import numpy as np
import os
from surprise import Dataset
from surprise import Reader
from surprise import SVD
from surprise import KNNWithMeans
from surprise import accuracy
from collections import defaultdict
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
# 1.A. Merge all the provided CSVs into one dataFrame. [2 Marks]
# Function to extract names of all files from OS
# Before 
def find_csv_files():
    suffix=".csv"
    filenames = os.listdir('.')
    return([filename for filename in filenames if filename.endswith( suffix )])

df_master = pd.DataFrame()
for f in find_csv_files():
    df_master = pd.concat([df_master, pd.read_csv(f)])

# %%
# Reset index of the combined dataframe
df_master.reset_index(drop=True, inplace=True)

# Display combined dataframe basic information
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1415133 entries, 0 to 1415132
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1415133 non-null  object
#  1   date       1415133 non-null  object
#  2   lang       1415133 non-null  object
#  3   country    1415133 non-null  object
#  4   source     1415133 non-null  object
#  5   domain     1415133 non-null  object
#  6   score      1351644 non-null  float64
#  7   score_max  1351644 non-null  float64
#  8   extract    1395772 non-null  object
#  9   author     1351931 non-null  object
#  10  product    1415132 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 118.8+ MB

# %%
# 1.B Explore, understand the Data and share at least 2 observations.
df_master.shape
# Out:
# (1415133, 11)

# %%
df_master.isnull().sum()
# Out:
# phone_url        0
# date             0
# lang             0
# country          0
# source           0
# domain           0
# score        63489
# score_max    63489
# extract      19361
# author       63202
# product          1
# dtype: int64

# %%
# Observations 
# There are 11 Columns and 1.4 mn records to analyse i.e. a huge dat set.
# There are signifiant number of null rows in the recors as seen from info in score, score_max, extract and author columns.

# %%
# 1.C Round off scores to the nearest integers. [3 Marks]
df_master['score']=df_master['score'].apply(np.round)

# %%
df_master
# Out:
#                                 phone_url       date lang country  \
# 0          /cellphones/samsung-galaxy-s8/   5/2/2017   en      us
# 1          /cellphones/samsung-galaxy-s8/  4/28/2017   en      us
# 2          /cellphones/samsung-galaxy-s8/   5/4/2017   en      us
# 3          /cellphones/samsung-galaxy-s8/   5/2/2017   en      us
# 4          /cellphones/samsung-galaxy-s8/  5/11/2017   en      us
# ...                                   ...        ...  ...     ...
# 1415128  /cellphones/sony-ericsson-z710i/   8/7/2006   fr      fr
# 1415129  /cellphones/sony-ericsson-z710i/   8/5/2006   fr      fr
# 1415130  /cellphones/sony-ericsson-z710i/  7/19/2006   fr      fr
# 1415131  /cellphones/sony-ericsson-z710i/   7/9/2006   fr      fr
# 1415132  /cellphones/sony-ericsson-z710i/  6/27/2006   fr      fr
#
#                    source               domain  score  score_max  \
# 0        Verizon Wireless  verizonwireless.com   10.0       10.0
# 1             Phone Arena       phonearena.com   10.0       10.0
# 2                  Amazon           amazon.com    6.0       10.0
# 3                 Samsung          samsung.com    9.0       10.0
# 4        Verizon Wireless  verizonwireless.com    4.0       10.0
# ...                   ...                  ...    ...        ...
# 1415128       GraphMobile      graphmobile.com   10.0       10.0
# 1415129       GraphMobile      graphmobile.com    9.0       10.0
# 1415130       GraphMobile      graphmobile.com   10.0       10.0
# 1415131       GraphMobile      graphmobile.com    9.0       10.0
# 1415132       GraphMobile      graphmobile.com   10.0       10.0
#
#                                                    extract       author  \
# 0        As a diehard Samsung fan who has had every Sam...   CarolAnn35
# 1        Love the phone. the phone is sleek and smooth ...    james0923
# 2        Adequate feel. Nice heft. Processor's still sl...     R. Craig
# 3        Never disappointed. One of the reasons I've be...  Buster2020
# 4        I've now found that i'm in a group of people t...   S Ate Mine
# ...                                                    ...          ...
# 1415128  Pour info il est sur amazon.de a 212.99€ s'il ...          NaN
# 1415129  Habitué à samsung sony nous sort 1 jolie clam ...          NaN
# 1415130  Pour les gens qui ne regarde pas Il fait mp3, ...          NaN
# 1415131                  C vrai que sans le mp3 c moyen...          NaN
# 1415132                  Il lui manque le mp3 quel dommage          NaN
#
#                                                    product
# 0                                        Samsung Galaxy S8
# 1                                        Samsung Galaxy S8
# 2        Samsung Galaxy S8 (64GB) G950U 5.8" 4G LTE Unl...
# 3                            Samsung Galaxy S8 64GB (AT&T)
# 4                                        Samsung Galaxy S8
# ...                                                    ...
# 1415128                                Sony-Ericsson Z710i
# 1415129                                Sony-Ericsson Z710i
# 1415130                                Sony-Ericsson Z710i
# 1415131                                Sony-Ericsson Z710i
# 1415132                                Sony-Ericsson Z710i
#
# [1415133 rows x 11 columns]

# %%
# 1.D Check for missing values. Impute the missing values, if any. 
df_master['score_max'].value_counts()
# Out:
# 10.0    1351644
# Name: score_max, dtype: int64

# %%
# Since only one value with no variation dropping this column.
df_master.drop('score_max',axis=1,inplace=True)

# %%
# Delete the row where product is mising its only one row 
df_master[df_master['product'].isna()]
# Out:
#                                 phone_url       date lang country  source  \
# 802795  /cellphones/samsung-galaxy-s-iii/  1/22/2014   de      de  Amazon
#
#            domain  score                                            extract  \
# 802795  amazon.de   10.0  Bestes Smartphone was ich bisher hatte :) öafk...
#
#        author product
# 802795    NaN     NaN

# %%
df_master.dropna(axis=0, subset=['product'], inplace=True)

# %%
# Delete all the rows where author is null 
# Dropping records with null values in author
df_master.dropna(axis=0, subset=['author'], inplace=True)

# %%
df_master.isnull().sum()
# Out:
# phone_url        0
# date             0
# lang             0
# country          0
# source           0
# domain           0
# score        60893
# extract      15515
# author           0
# product          0
# dtype: int64

# %%
# Where score is missing replace it with the mean score
df_master['score'].fillna(np.round(df_master['score'].mean()),inplace=True)

# %%
# Where extract is missing repace it with blanks
df_master['extract'].replace({np.nan: ' '},inplace=True)

# %%
#1.E Check for duplicate values and remove them, if any. [2 Marks]
df_master = df_master.loc[~df_master.duplicated(keep = 'first')]

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1346881 entries, 0 to 1415125
# Data columns (total 10 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1346881 non-null  object
#  1   date       1346881 non-null  object
#  2   lang       1346881 non-null  object
#  3   country    1346881 non-null  object
#  4   source     1346881 non-null  object
#  5   domain     1346881 non-null  object
#  6   score      1346881 non-null  float64
#  7   extract    1346881 non-null  object
#  8   author     1346881 non-null  object
#  9   product    1346881 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 113.0+ MB

# %%
#1.F Keep only 1 Million data samples. Use random state=612. [2 Marks]
df_subSet = df_master.sample(1000000, random_state=612).copy().reset_index(drop=True)

# %%
#1.G Drop irrelevant features. Keep features like Author, Product, and Score. [2 Marks]
df_analysis = df_subSet[["country", "author", "product", "score"]].copy()

# %% [markdown]
# ### 2.Answer the following questions. [10 Marks]
# #### A.Identify the most rated products. [3 Marks]
# #### B.Identify the users with most number of reviews. [3 Marks]
# #### C.Select the data with products having more than 50 ratings and users who have given more than 50 ratings. Report the shape of the final dataset. [4 Marks]

# %%
#2.A Identify the most rated products.
df_analysis['product'].value_counts()[:10]
# Out:
# Lenovo Vibe K4 Note (White,16GB)                3847
# Lenovo Vibe K4 Note (Black, 16GB)               3197
# OnePlus 3 (Graphite, 64 GB)                     3014
# OnePlus 3 (Soft Gold, 64 GB)                    2666
# Samsung Galaxy Express I8730                    2019
# Huawei P8lite zwart / 16 GB                     1971
# Lenovo Vibe K5 (Gold, VoLTE update)             1897
# Samsung Galaxy S6 zwart / 32 GB                 1760
# Lenovo Vibe K5 (Grey, VoLTE update)             1566
# Lenovo Used Lenovo Zuk Z1 (Space Grey, 64GB)    1460
# Name: product, dtype: int64

# %%
#2.B Identify the users with most number of reviews.
df_analysis['author'].value_counts()[:10]
# Out:
# Amazon Customer    57169
# Cliente Amazon     14349
# e-bit               6254
# Client d'Amazon     5703
# Amazon Kunde        3557
# Anonymous           2051
# einer Kundin        1894
# einem Kunden        1435
# unknown             1283
# Anonymous           1083
# Name: author, dtype: int64

# %%
#2.C Select the data with products having more than 50 ratings and users who have given more than 50 ratings. 
# Report the shape of the final dataset. [4 Marks]
# selecting products which had atleast 50 reviews.

df_analysis['p_count'] = df_analysis.groupby(['product'])['score'].transform('count')
df_analysis['a_count'] = df_analysis.groupby(['author'])['score'].transform('count')

# %%
df_gt_50_reviews = df_analysis[(df_analysis['p_count']>50) & (df_analysis['a_count']>50)]
df_gt_50_reviews
# Out:
#        country           author  \
# 1           in  Amazon Customer
# 12          fr  Client d'Amazon
# 15          nl          unknown
# 21          gb  Amazon Customer
# 29          in  Amazon Customer
# ...        ...              ...
# 999979      de              Tim
# 999980      gb  Amazon Customer
# 999984      de     Amazon-Kunde
# 999985      fr  Client d'Amazon
# 999988      in  Amazon Customer
#
#                                                   product  score  p_count  \
# 1              Asus Zenfone 2 Laser ZE500KL (Black, 16GB)    4.0       82
# 12      Buyus Etui Housse Luxe Portefeuille Samsung Ga...   10.0       64
# 15                   Samsung Samsung Galaxy A5 2016 - Wit   10.0       65
# 21      Samsung Galaxy S7 Edge 32GB UK SIM-Free Smartp...   10.0      148
# 29          OnePlus 3T (Soft Gold, 6GB RAM + 64GB memory)   10.0     1000
# ...                                                   ...    ...      ...
# 999979  Samsung Galaxy S Duos S7562 Smartphone (Qualco...    8.0       88
# 999980  Doro PhoneEasy 612i GSM Sim Free Mobile Phone ...   10.0      176
# 999984  HTC Desire X Smartphone (1 GHz Dual-Core Proze...   10.0      191
# 999985  EasyAcc Coque Samsung Galaxy A3 2016, EasyAcc ...   10.0       63
# 999988                   HTC Desire 620G (Santroni White)    2.0      568
#
#         a_count
# 1         57169
# 12         5703
# 15         1283
# 21        57169
# 29        57169
# ...         ...
# 999979      167
# 999980    57169
# 999984      383
# 999985     5703
# 999988    57169
#
# [108776 rows x 6 columns]

# %%
df_gt_50_reviews.shape
# Out:
# (108776, 6)

# %% [markdown]
# ## 3 Build a popularity based model and recommend top 5 mobile phones. [5 Marks]

# %%
# Build a popularity based model and recommend top 5 mobile phones. [5 Marks]
# Display top 5 mobile phones by rating in the world
# Calculating the mean score for a product by grouping it.
# Recoomendation idea to get higherst rating with highest count of rating product got
# This removes the bias that if one rating was high the product gets promoted
# Count of ratings received is also consdiered a parameter to suggest rating.
ratings_mean_count = pd.DataFrame(df_analysis.groupby('product')['score'].mean()) 
ratings_mean_count['rating_counts'] = pd.DataFrame(df_analysis.groupby('product')['score'].count()) 
ratings_mean_count.sort_values(by=['score','rating_counts'], ascending=[False,False]).head()

# However since the date data is too wide we should have recommended based on monthly or yearly populatiry. 
# A model popular in one time preiod should not be recommended in another period
# Out:
#                                                     score  rating_counts
# product
# Samsung Galaxy Note5                                 10.0            149
# Motorola Smartphone Motorola Moto X Desbloquead...   10.0            142
# Nokia Smartphone Nokia Lumia 520 Desbloqueado O...   10.0            133
# Motorola Smartphone Motorola Moto G Dual Chip D...   10.0            130
# Samsung Smartphone Dual Chip Samsung Galaxy SII...   10.0            128

# %% [markdown]
# ## 4. Build a collaborative filtering model using SVD. You can use SVD from surprise or build it from scratch(Note: Incase you’re building it from scratch you can limit your data points to 5000 samples if you face memory issues). Build a collaborative filtering model using kNNWithMeans from surprise. You can try both user-based and item-based model. [10 Marks]

# %%
reader = Reader(rating_scale=(1, 10))
data = Dataset.load_from_df(df_gt_50_reviews[['author', 'product', 'score']], reader)
algo_svd = SVD(n_epochs=10)

# %%
trainset, testset = train_test_split(data, test_size=.2,random_state=612)

# %%
# Training model svd
algo_svd.fit(trainset)

# %%
# Building user-user collaborative filter model KNNWithMeans
algo_user = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True})
algo_user.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
# Build item-item collaborative filter model
algo_item = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo_item.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# ## 5. Evaluate the collaborative model. Print RMSE value.

# %%
# Get prediction for svd based collaborative filtering model
# get RMSE for svd 
svd_pred = algo_svd.test(testset)
print("SVD-based Model : Test Set")
accuracy.rmse(svd_pred, verbose=True)

# get RMSE for user-user collaborative filtering model
usr_pred = algo_user.test(testset)
print("\nUser-User Model : Test Set")
accuracy.rmse(usr_pred, verbose=True)

# get RMSE for item-item collaborative filtering model
itm_pred = algo_item.test(testset)
print("\nItem-Item Model : Test Set")
accuracy.rmse(itm_pred, verbose=True)
# Out:
# SVD-based Model : Test Set
# RMSE: 2.6185
#
# User-User Model : Test Set
# RMSE: 2.7538
#
# Item-Item Model : Test Set
# RMSE: 2.6826
# 2.682600168588943

# %% [markdown]
# ## 6. Predict score (average rating) for test users. [2 Marks]

# %%
# SVD 
svd_pred_df = pd.DataFrame(svd_pred)
svd_pred_df.head(5)
# Out:
#                uid                                                iid  r_ui  \
# 0        Francesco  Huawei P9 Lite Smartphone, LTE, Display 5.2'' ...  10.0
# 1           Deepak                        Nokia 215 (Dual SIM, Black)   6.0
# 2                .  Samsung Galaxy S3 I9300 Unlocked 16GB (Marble ...   6.0
# 3  Amazon Customer       OnePlus 3T (Gunmetal, 6GB RAM + 64GB memory)  10.0
# 4             John                                 Sony Ericsson W580   8.0
#
#         est                    details
# 0  9.151644  {'was_impossible': False}
# 1  7.543952  {'was_impossible': False}
# 2  7.265435  {'was_impossible': False}
# 3  8.523530  {'was_impossible': False}
# 4  8.173370  {'was_impossible': False}

# %%
#User-User CF
usr_pred_df = pd.DataFrame(usr_pred)
usr_pred_df.head(5)
# Out:
#                uid                                                iid  r_ui  \
# 0        Francesco  Huawei P9 Lite Smartphone, LTE, Display 5.2'' ...  10.0
# 1           Deepak                        Nokia 215 (Dual SIM, Black)   6.0
# 2                .  Samsung Galaxy S3 I9300 Unlocked 16GB (Marble ...   6.0
# 3  Amazon Customer       OnePlus 3T (Gunmetal, 6GB RAM + 64GB memory)  10.0
# 4             John                                 Sony Ericsson W580   8.0
#
#         est                                    details
# 0  9.191791  {'actual_k': 50, 'was_impossible': False}
# 1  9.666667   {'actual_k': 1, 'was_impossible': False}
# 2  6.000000   {'actual_k': 1, 'was_impossible': False}
# 3  8.680000  {'actual_k': 50, 'was_impossible': False}
# 4  8.183266   {'actual_k': 7, 'was_impossible': False}

# %%
#Item-Item CF
itm_pred_df = pd.DataFrame(itm_pred)
itm_pred_df.head(5)
# Out:
#                uid                                                iid  r_ui  \
# 0        Francesco  Huawei P9 Lite Smartphone, LTE, Display 5.2'' ...  10.0
# 1           Deepak                        Nokia 215 (Dual SIM, Black)   6.0
# 2                .  Samsung Galaxy S3 I9300 Unlocked 16GB (Marble ...   6.0
# 3  Amazon Customer       OnePlus 3T (Gunmetal, 6GB RAM + 64GB memory)  10.0
# 4             John                                 Sony Ericsson W580   8.0
#
#         est                                    details
# 0  9.260736  {'actual_k': 50, 'was_impossible': False}
# 1  8.752487   {'actual_k': 7, 'was_impossible': False}
# 2  6.028074   {'actual_k': 6, 'was_impossible': False}
# 3  8.680000  {'actual_k': 50, 'was_impossible': False}
# 4  7.029029   {'actual_k': 7, 'was_impossible': False}

# %% [markdown]
# ## 7. Report your findings and inferences.

# %% [markdown]
# #### 1. Based on the results we got on the accuracy (RMSE) scores. SVD has the lowest RMSE
# #### 2. However the RMSE of ~2.5 is still very high.
# #### 3. Item Item CF takes maximum time to compute.
# #### 4. Given that exact prediction is not the objective here but old recommendation all three models do a good job.
# #### 5. Needless to say the people have generally given good rating i.e. around 8 so there is bias in data. However recommendations are less impacted due to the same.

# %% [markdown]
# ## 8. Try and recommend top 5 products for test users.

# %%
top_5_prod_recos = svd_pred_df.groupby('uid').head(5).reset_index(drop=True)

# %%
pd.set_option('max_columns',None)
pd.set_option('max_rows',None)
top_5_prod_recos.sort_values('uid')
# Out:
#                                   uid  \
# 1299                                #
# 1296                                #
# 1442                                #
# 1240                                #
# 739                                 #
# 2                                   .
# 2180                                .
# 1059                                .
# 1975                                .
# 1372                         ????????
# 1111                         ????????
# 774                          ????????
# 299                          ????????
# 212                          ????????
# 581                        ??????????
# 419                        ??????????
# 318                        ??????????
# 715                        ??????????
# 95                         ??????????
# 1626                     ????????????
# 1348                     ????????????
# 1850                     ????????????
# 1016                     ????????????
# 941                      ????????????
# 1036      ???????????? ??????????????
# 1064      ???????????? ??????????????
# 2900      ???????????? ??????????????
# 647       ???????????? ??????????????
# 1669      ???????????? ??????????????
# 1932                   ??????????????
# 1700                   ??????????????
# 142                    ??????????????
# 1483                   ??????????????
# 182                    ??????????????
# 570         ?????????????? ??????????
# 1717        ?????????????? ??????????
# 316         ?????????????? ??????????
# 1925        ?????????????? ??????????
# 726         ?????????????? ??????????
# 2760      ?????????????? ????????????
# 2615      ?????????????? ????????????
# 2933      ?????????????? ????????????
# 2316      ?????????????? ????????????
# 858       ?????????????? ????????????
# 700     ?????????????? ??????????????
# 2554    ?????????????? ??????????????
# 1291    ?????????????? ??????????????
# 2013    ?????????????? ??????????????
# 1455    ?????????????? ??????????????
# 2645                 ????????????????
# 2703                 ????????????????
# 185                  ????????????????
# 2107                 ????????????????
# 1999                 ????????????????
# 2908  ???????????????? ??????????????
# 1722  ???????????????? ??????????????
# 2887  ???????????????? ??????????????
# 1950               ?????????????????�
# 393                ?????????????????�
# 2044               ?????????????????�
# 2208               ?????????????????�
# 1585               ?????????????????�
# 96                     ?????????�????
# 308                    ?????????�????
# 562                    ?????????�????
# 863                    ?????????�????
# 1229                   ?????????�????
# 2894                     ???????�????
# 2071                     ???????�????
# 2454                     ???????�????
# 880                      ???????�????
# 2736                     ???????�????
# 765                      ?????�??????
# 2453                     ?????�??????
# 1257                     ?????�??????
# 441                      ?????�??????
# 2045                     ?????�??????
# 1590                       ???�??????
# 3107                       ???�??????
# 3102                       ???�??????
# 2120                       ???�??????
# 1293                       ???�??????
# 1776                               AJ
# 1185                               AJ
# 2143                               AJ
# 1271                               AJ
# 1817                               AJ
# 1743                         Abhishek
# 2419                         Abhishek
# 1588                         Abhishek
# 1922                         Abhishek
# 2527                         Abhishek
# 1764                             Adam
# 2794                             Adam
# 2097                             Adam
# 2826                             Adam
# 1156                             Adam
# 1461                           Adrian
# 1448                           Adrian
# 872                            Adrian
# 2171                           Adrian
# 711                            Adrian
# 538                           Aksisey
# 2501                          Aksisey
# 1749                          Aksisey
# 1942                          Aksisey
# 2433                          Aksisey
# 2696                               Al
# 3009                               Al
# 2804                               Al
# 1370                               Al
# 205                              Alan
# 2571                             Alan
# 3016                             Alan
# 1759                             Alan
# 3032                             Alan
# 2720                           Albert
# 2958                           Albert
# 2147                           Albert
# 1551                           Albert
# 157                            Albert
# 301                           Alberto
# 616                           Alberto
# 899                           Alberto
# 231                           Alberto
# 281                           Alberto
# 824                               Ale
# 358                               Ale
# 898                               Ale
# 1675                              Ale
# 473                               Ale
# 1431                        Alejandro
# 1584                        Alejandro
# 1674                        Alejandro
# 1151                        Alejandro
# 2169                        Alejandro
# 2146                       Alessandra
# 2534                       Alessandra
# 618                        Alessandra
# 330                        Alessandra
# 2034                       Alessandra
# 1504                       Alessandro
# 1502                       Alessandro
# 1148                       Alessandro
# 1050                       Alessandro
# 44                         Alessandro
# 560                           Alessio
# 1116                          Alessio
# 2215                          Alessio
# 2128                          Alessio
# 2257                          Alessio
# 210                              Alex
# 19                               Alex
# 424                              Alex
# 364                              Alex
# 145                              Alex
# 1507                        Alexander
# 1189                        Alexander
# 1330                        Alexander
# 1071                        Alexander
# 792                         Alexander
# 2897                        Alexandra
# 2096                        Alexandra
# 3063                        Alexandra
# 1523                           Alexis
# 958                            Alexis
# 1718                           Alexis
# 2251                           Alexis
# 2072                           Alexis
# 3011                          Alfonso
# 1904                          Alfonso
# 2614                          Alfonso
# 682                           Alfonso
# 2547                          Alfonso
# 3125                          Alfredo
# 2812                          Alfredo
# 3089                          Alfredo
# 2031                          Alfredo
# 2979                          Alfredo
# 2675                              Ali
# 2338                              Ali
# 2755                              Ali
# 1530                              Ali
# 2016                              Ali
# 2502                            Alias
# 2822                            Alias
# 1485                            Alias
# 2939                            Alias
# 2392                            Alias
# 1222                            Alice
# 776                             Alice
# 1753                            Alice
# 989                             Alice
# 1970                            Alice
# 2401                           Alicia
# 1076                           Alicia
# 36                             Alicia
# 1159                           Alicia
# 2631                           Alicia
# 2237                           Alvaro
# 539                            Alvaro
# 504                            Alvaro
# 2601                           Alvaro
# 2742                           Alvaro
# 270                            Amanda
# 1881                           Amanda
# 1955                           Amanda
# 1897                           Amanda
# 1659                           Amanda
# 7                     Amazon Customer
# 6                     Amazon Customer
# 8                     Amazon Customer
# 3                     Amazon Customer
# 9                     Amazon Customer
# 186                      Amazon Kunde
# 23                       Amazon Kunde
# 13                       Amazon Kunde
# 58                       Amazon Kunde
# 12                       Amazon Kunde
# 45                       Amazon-Kunde
# 60                       Amazon-Kunde
# 253                      Amazon-Kunde
# 162                      Amazon-Kunde
# 295                      Amazon-Kunde
# 593                              Amit
# 2552                             Amit
# 2708                             Amit
# 2670                             Amit
# 1706                             Amit
# 2620                              Amy
# 2677                              Amy
# 1837                              Amy
# 187                               Amy
# 2673                              Amy
# 2820                              Ana
# 2650                              Ana
# 2707                              Ana
# 2116                              Ana
# 2828                              Ana
# 2394                            Andre
# 2266                            Andre
# 1480                            Andre
# 2750                            Andre
# 2756                            Andre
# 435                            Andrea
# 133                            Andrea
# 1013                           Andrea
# 1115                           Andrea
# 871                            Andrea
# 1526                          Andreas
# 2373                          Andreas
# 1974                          Andreas
# 781                           Andreas
# 775                           Andreas
# 1650                           Andres
# 2676                           Andres
# 1902                           Andres
# 2681                           Andres
# 3068                           Andres
# 317                            Andrew
# 1672                           Andrew
# 149                            Andrew
# 1605                           Andrew
# 1645                           Andrew
# 598                             André
# 2519                            André
# 917                             André
# 639                             André
# 694                             André
# 525                              Andy
# 1273                             Andy
# 153                              Andy
# 345                              Andy
# 945                              Andy
# 1561                            Angel
# 1941                            Angel
# 1048                            Angel
# 634                             Angel
# 2340                            Angel
# 2307                           Angela
# 3086                           Angela
# 2560                           Angela
# 807                            Angela
# 3114                           Angela
# 1814                           Angelo
# 479                            Angelo
# 992                            Angelo
# 1600                           Angelo
# 1843                           Angelo
# 3052                            Anita
# 2996                            Anita
# 159                             Anita
# 910                             Anita
# 1933                            Anita
# 1357                             Anja
# 3085                             Anja
# 1848                             Anja
# 2798                             Anja
# 615                              Anna
# 1069                             Anna
# 219                              Anna
# 1471                             Anna
# 84                               Anna
# 1546                             Anne
# 1337                             Anne
# 2037                             Anne
# 1255                             Anne
# 88                               Anne
# 164                             Annie
# 1919                            Annie
# 2261                            Annie
# 123                             Annie
# 1792                           Anonym
# 1578                           Anonym
# 343                            Anonym
# 831                            Anonym
# 978                            Anonym
# 1379                          Anonyme
# 1006                          Anonyme
# 1557                          Anonyme
# 1085                          Anonyme
# 194                           Anonyme
# 135                         Anonymous
# 410                         Anonymous
# 406                         Anonymous
# 184                         Anonymous
# 359                         Anonymous
# 256                        Anonymous
# 43                         Anonymous
# 272                        Anonymous
# 71                         Anonymous
# 223                        Anonymous
# 2091                          Anthony
# 2551                          Anthony
# 290                           Anthony
# 2700                          Anthony
# 508                           Anthony
# 2911                            Anton
# 802                             Anton
# 2754                            Anton
# 2295                            Anton
# 3065                            Anton
# 591                           Antonio
# 305                           Antonio
# 176                           Antonio
# 600                           Antonio
# 457                           Antonio
# 1265                         Anónimo
# 207                          Anónimo
# 2006                         Anónimo
# 2191                         Anónimo
# 1798                         Anónimo
# 120                           Anônimo
# 565                           Anônimo
# 994                           Anônimo
# 768                           Anônimo
# 687                           Anônimo
# 1509                             Arun
# 165                              Arun
# 1429                             Arun
# 1550                             Arun
# 2639                             Arun
# 2916                           Ashish
# 2792                           Ashish
# 719                            Ashish
# 915                            Ashish
# 2021                           Ashish
# 363                            Ashley
# 411                            Ashley
# 606                            Ashley
# 1620                           Ashley
# 1447                           Ashley
# 433                           Barbara
# 1126                          Barbara
# 1801                          Barbara
# 1877                          Barbara
# 375                           Barbara
# 383                              Bart
# 496                              Bart
# 552                              Bart
# 1235                             Bart
# 1204                             Bart
# 1698                              Ben
# 444                               Ben
# 282                               Ben
# 1462                              Ben
# 2211                              Ben
# 337                          Benjamin
# 2277                         Benjamin
# 2923                         Benjamin
# 3130                         Benjamin
# 3127                         Benjamin
# 1574                            Bernd
# 2109                            Bernd
# 2647                            Bernd
# 2377                            Bernd
# 2597                            Bernd
# 2537                             Bert
# 2082                             Bert
# 2683                             Bert
# 214                              Bert
# 1797                             Bert
# 2075                     Bezlikiy_Djo
# 234                      Bezlikiy_Djo
# 1816                     Bezlikiy_Djo
# 1081                     Bezlikiy_Djo
# 1670                     Bezlikiy_Djo
# 192                              Bill
# 1810                             Bill
# 3044                             Bill
# 1872                             Bill
# 2328                             Bill
# 1130                              Bob
# 1547                              Bob
# 979                               Bob
# 89                                Bob
# 2196                              Bob
# 2351                          Brandon
# 2955                          Brandon
# 1773                          Brandon
# 2862                          Brandon
# 2815                          Brandon
# 2350                            Brian
# 1306                            Brian
# 379                             Brian
# 54                              Brian
# 1363                            Brian
# 638                             Bruno
# 1010                            Bruno
# 1746                            Bruno
# 3121                            Bruno
# 1533                            Bruno
# 599                            Capyto
# 1989                           Capyto
# 2763                           Capyto
# 2263                           Capyto
# 557                            Capyto
# 814                             Carlo
# 2102                            Carlo
# 1420                            Carlo
# 2302                            Carlo
# 2323                            Carlo
# 976                            Carlos
# 1463                           Carlos
# 342                            Carlos
# 269                            Carlos
# 642                            Carlos
# 2555                           Carmen
# 450                            Carmen
# 2535                           Carmen
# 2626                           Carmen
# 1868                           Carmen
# 2474                            Carol
# 1809                            Carol
# 2083                            Carol
# 823                             Carol
# 2494                            Carol
# 2452                            Cesar
# 1190                            Cesar
# 2065                            Cesar
# 2905                            Cesar
# 2829                            Cesar
# 3112                          Charles
# 1643                          Charles
# 1301                          Charles
# 3073                          Charles
# 2542                          Charles
# 1365                          Charlie
# 2480                          Charlie
# 2435                          Charlie
# 2439                          Charlie
# 1976                          Charlie
# 2791                           Chiara
# 3050                           Chiara
# 1972                           Chiara
# 3118                           Chiara
# 2550                           Chiara
# 218                             Chris
# 515                             Chris
# 549                             Chris
# 553                             Chris
# 40                              Chris
# 1321                        Christian
# 80                          Christian
# 1030                        Christian
# 163                         Christian
# 1176                        Christian
# 2974                        Christina
# 934                         Christina
# 2470                        Christina
# 510                         Christina
# 1951                        Christina
# 2175                        Christine
# 1435                        Christine
# 2413                        Christine
# 2049                        Christine
# 1614                        Christine
# 3054                       Christophe
# 2222                       Christophe
# 1495                       Christophe
# 1366                      Christopher
# 1632                      Christopher
# 680                       Christopher
# 1529                      Christopher
# 1418                      Christopher
# 2326                            Cindy
# 1684                            Cindy
# 2306                            Cindy
# 1997                            Cindy
# 2069                            Cindy
# 2220                          Claudia
# 2442                          Claudia
# 94                            Claudia
# 403                           Claudia
# 1263                          Claudia
# 513                           Claudio
# 1939                          Claudio
# 1707                          Claudio
# 2121                          Claudio
# 2336                          Claudio
# 1988                    Client Amazon
# 2704                    Client Amazon
# 2312                    Client Amazon
# 2810                    Client Amazon
# 1341                    Client Amazon
# 115                   Client d'Amazon
# 70                    Client d'Amazon
# 33                    Client d'Amazon
# 57                    Client d'Amazon
# 59                    Client d'Amazon
# 20                     Cliente Amazon
# 22                     Cliente Amazon
# 32                     Cliente Amazon
# 14                     Cliente Amazon
# 11                     Cliente Amazon
# 1519                Cliente de Amazon
# 954                 Cliente de Amazon
# 670                 Cliente de Amazon
# 280                 Cliente de Amazon
# 911                 Cliente de Amazon
# 53                           Cristian
# 844                          Cristian
# 1322                         Cristian
# 2155                         Cristian
# 1990                         Cristian
# 2193                         Cristina
# 2920                         Cristina
# 652                          Cristina
# 445                          Cristina
# 674                          Cristina
# 3012                                D
# 2711                                D
# 3101                                D
# 655                             DAVID
# 3001                            DAVID
# 1755                            DAVID
# 2406                            DAVID
# 3075                            DAVID
# 1392                               DJ
# 626                                DJ
# 3017                               DJ
# 1342                               DJ
# 2616                               DJ
# 1427                              Dan
# 2010                              Dan
# 413                               Dan
# 2015                              Dan
# 1780                              Dan
# 1100                             Dani
# 2788                             Dani
# 2956                             Dani
# 2970                             Dani
# 2637                             Dani
# 365                            Daniel
# 304                            Daniel
# 493                            Daniel
# 681                            Daniel
# 1099                           Daniel
# 2135                          Daniela
# 48                            Daniela
# 1750                          Daniela
# 469                           Daniela
# 1602                          Daniela
# 400                           Daniele
# 721                           Daniele
# 1556                          Daniele
# 454                           Daniele
# 1623                          Daniele
# 861                            Danilo
# 617                            Danilo
# 455                            Danilo
# 362                            Danilo
# 555                            Danilo
# 1840                            Danny
# 2249                            Danny
# 1768                            Danny
# 2334                            Danny
# 1703                            Danny
# 710                             Dario
# 1587                            Dario
# 1017                            Dario
# 1783                            Dario
# 787                             Dario
# 793                              Dave
# 1247                             Dave
# 1894                             Dave
# 189                              Dave
# 251                              Dave
# 21                              David
# 128                             David
# 209                             David
# 109                             David
# 170                             David
# 27                             Davide
# 527                            Davide
# 657                            Davide
# 180                            Davide
# 488                            Davide
# 2289                              Dee
# 2830                              Dee
# 2769                              Dee
# 2585                              Dee
# 2879                              Dee
# 580                            Deepak
# 1978                           Deepak
# 972                            Deepak
# 1466                           Deepak
# 1                              Deepak
# 1986                            Denis
# 2842                            Denis
# 2515                            Denis
# 2355                            Denis
# 1562                            Denis
# 2315                           Denise
# 1146                           Denise
# 2622                           Denise
# 491                            Denise
# 440                            Denise
# 913                            Dennis
# 1252                           Dennis
# 198                            Dennis
# 323                            Dennis
# 168                            Dennis
# 1709                            Diana
# 1594                            Diana
# 859                             Diana
# 462                             Diana
# 1610                            Diana
# 813                             Diego
# 914                             Diego
# 1391                            Diego
# 1362                            Diego
# 1113                            Diego
# 1802                             Dirk
# 2385                             Dirk
# 2540                             Dirk
# 2628                             Dirk
# 1512                             Dirk
# 755                          Domenico
# 691                          Domenico
# 83                           Domenico
# 1161                         Domenico
# 2207                         Domenico
# 3115                          Dominik
# 3081                          Dominik
# 2823                               Ed
# 99                                 Ed
# 2824                               Ed
# 2544                               Ed
# 2972                               Ed
# 2553                          Eduardo
# 2101                          Eduardo
# 1032                          Eduardo
# 41                            Eduardo
# 277                           Eduardo
# 2430                            Elena
# 1732                            Elena
# 2505                            Elena
# 485                             Elena
# 206                             Elena
# 2393                            Elisa
# 1098                            Elisa
# 1954                            Elisa
# 2225                            Elisa
# 892                             Elisa
# 1411                         Emanuele
# 2404                         Emanuele
# 2714                         Emanuele
# 1317                         Emanuele
# 2938                         Emanuele
# 2799                           Emilio
# 843                            Emilio
# 2962                           Emilio
# 2276                             Emma
# 2499                             Emma
# 1397                             Emma
# 2746                             Emma
# 2718                             Emma
# 2033                           Enrico
# 2179                           Enrico
# 2199                           Enrico
# 2343                           Enrico
# 1665                           Enrico
# 790                           Enrique
# 2947                          Enrique
# 16                            Enrique
# 1003                          Enrique
# 2592                          Enrique
# 2079                             Eric
# 279                              Eric
# 1559                             Eric
# 1527                             Eric
# 2011                             Eric
# 1641                             Erik
# 238                              Erik
# 2087                             Erik
# 1687                             Erik
# 1155                             Erik
# 2640                            Erkek
# 1108                            Erkek
# 1066                            Erkek
# 1388                            Erkek
# 1243                            Erkek
# 1861                              Eva
# 143                               Eva
# 453                               Eva
# 1182                              Eva
# 1019                              Eva
# 178                             Fabio
# 107                             Fabio
# 640                             Fabio
# 412                             Fabio
# 735                             Fabio
# 1826                         Fabrizio
# 874                          Fabrizio
# 2002                         Fabrizio
# 389                          Fabrizio
# 1244                         Fabrizio
# 486                          Federico
# 255                          Federico
# 1567                         Federico
# 2032                         Federico
# 1528                         Federico
# 2301                            Felix
# 175                             Felix
# 2488                            Felix
# 248                             Felix
# 242                             Felix
# 1376                         Fernando
# 82                           Fernando
# 1697                         Fernando
# 796                          Fernando
# 517                          Fernando
# 923                           Filippo
# 838                           Filippo
# 174                           Filippo
# 2086                          Filippo
# 28                            Filippo
# 875                 Flipkart Customer
# 1844                Flipkart Customer
# 1090                Flipkart Customer
# 1437                Flipkart Customer
# 1867                Flipkart Customer
# 2476                              Flo
# 3038                              Flo
# 2672                              Flo
# 3053                          Florian
# 2441                          Florian
# 1690                          Florian
# 2680                          Florian
# 2992                          Florian
# 2679                   Flype (Felipe)
# 778                              Fran
# 34                               Fran
# 2004                             Fran
# 1874                        Francesca
# 1057                        Francesca
# 2056                        Francesca
# 2112                        Francesca
# 546                         Francesca
# 105                         Francesco
# 35                          Francesco
# 0                           Francesco
# 246                         Francesco
# 226                         Francesco
# 1216                        Francisco
# 2242                        Francisco
# 211                         Francisco
# 1539                        Francisco
# 2148                        Francisco
# 2881                           Franco
# 1416                           Franco
# 2549                           Franco
# 386                            Franco
# 2855                           Franco
# 901                             Frank
# 1327                            Frank
# 1136                            Frank
# 1444                            Frank
# 1386                            Frank
# 249                              Fred
# 1142                             Fred
# 676                              Fred
# 699                              Fred
# 1769                             Fred
# 1886                                G
# 1326                                G
# 991                                 G
# 25                            Gabriel
# 427                           Gabriel
# 779                           Gabriel
# 1788                          Gabriel
# 1073                          Gabriel
# 888                          Gabriele
# 2268                         Gabriele
# 1475                         Gabriele
# 1878                         Gabriele
# 494                          Gabriele
# 3015                           Ganesh
# 2934                           Ganesh
# 3071                           Ganesh
# 2426                             Gary
# 3091                             Gary
# 2562                             Gary
# 2559                             Gary
# 3041                             Gary
# 2935                             Gast
# 1119                           Gaurav
# 1934                           Gaurav
# 1270                           Gaurav
# 1789                           Gaurav
# 1226                           Gaurav
# 1118                           George
# 1736                           George
# 1821                           George
# 1671                           George
# 1804                           George
# 1055                          Giacomo
# 2200                          Giacomo
# 2649                          Giacomo
# 2805                          Giacomo
# 651                           Giacomo
# 1138                         Gianluca
# 2081                         Gianluca
# 2335                         Gianluca
# 2229                         Gianluca
# 1906                         Gianluca
# 1781                           Gianni
# 3046                           Gianni
# 2110                          Giorgio
# 1308                          Giorgio
# 1568                          Giorgio
# 104                           Giorgio
# 390                           Giorgio
# 837                          Giovanni
# 499                          Giovanni
# 429                          Giovanni
# 302                          Giovanni
# 498                          Giovanni
# 2572                           Giulio
# 1779                           Giulio
# 2702                           Giulio
# 2352                           Giulio
# 2728                           Giulio
# 804                          Giuseppe
# 38                           Giuseppe
# 679                          Giuseppe
# 1232                         Giuseppe
# 1324                         Giuseppe
# 47                               Greg
# 2836                             Greg
# 361                              Greg
# 644                              Greg
# 315                              Greg
# 1380                            Guest
# 1402                            Guest
# 2274                            Guest
# 956                             Guest
# 882                             Guest
# 2186                            Guido
# 3049                            Guido
# 1640                            Guido
# 1838                            Guido
# 572                             Guido
# 3045                        Guillermo
# 1214                        Guillermo
# 2981                        Guillermo
# 2541                          Gustavo
# 2371                          Gustavo
# 3004                          Gustavo
# 2913                          Gustavo
# 1571                          Gustavo
# 1426                             Hans
# 2080                             Hans
# 1921                             Hans
# 764                              Hans
# 2567                             Hans
# 1423                            Harry
# 2395                            Harry
# 2521                            Harry
# 2591                            Harry
# 2332                            Harry
# 1949                          Heather
# 2170                          Heather
# 2152                          Heather
# 2050                          Heather
# 62                            Heather
# 1830                            Henry
# 2738                            Henry
# 967                             Henry
# 1909                            Henry
# 2767                            Henry
# 75                                Ian
# 384                               Ian
# 1371                              Ian
# 946                               Ian
# 1558                              Ian
# 1831                             Igor
# 526                              Igor
# 2099                             Igor
# 1766                             Igor
# 1267                             Ivan
# 1468                             Ivan
# 1506                             Ivan
# 1663                             Ivan
# 1604                             Ivan
# 2260                                J
# 1351                                J
# 2150                                J
# 2023                                J
# 2273                                J
# 519                                JB
# 1752                               JB
# 723                                JB
# 1936                               JB
# 1962                               JB
# 1944                               JD
# 2138                               JD
# 3098                               JD
# 3055                               JD
# 2729                               JD
# 2850                               JJ
# 2264                               JJ
# 2039                               JJ
# 2284                               JJ
# 2663                               JJ
# 2411                               JP
# 2398                               JP
# 2864                               JP
# 2825                               JP
# 2129                               JP
# 2320                               JR
# 734                                JR
# 2602                               JR
# 1993                               JR
# 1957                               JR
# 1338                             Jack
# 1731                             Jack
# 1778                             Jack
# 1998                             Jack
# 1673                             Jack
# 3093                            Jaime
# 3025                            Jaime
# 1691                            Jaime
# 2852                            Jaime
# 3100                            Jaime
# 533                              Jake
# 154                              Jake
# 87                               Jake
# 2244                             Jake
# 2504                             Jake
# 1705                            James
# 1544                            James
# 310                             James
# 1037                            James
# 483                             James
# 1336                              Jan
# 701                               Jan
# 1493                              Jan
# 29                                Jan
# 1331                              Jan
# 2980                             Jane
# 2428                             Jane
# 3024                             Jane
# 2931                            Jason
# 2438                            Jason
# 2865                            Jason
# 2790                            Jason
# 2928                            Jason
# 1238                             Javi
# 1233                             Javi
# 199                            Javier
# 237                            Javier
# 291                            Javier
# 288                            Javier
# 112                            Javier
# 1230                              Jay
# 2219                              Jay
# 886                               Jay
# 773                               Jay
# 1110                              Jay
# 2611                             Jean
# 2948                             Jean
# 394                              Jean
# 2564                             Jean
# 1221                             Jean
# 1143                             Jeff
# 1192                             Jeff
# 1940                             Jeff
# 2407                             Jeff
# 2076                             Jeff
# 1031                         Jennifer
# 1445                         Jennifer
# 2188                         Jennifer
# 846                          Jennifer
# 2281                         Jennifer
# 836                             Jenny
# 1573                            Jenny
# 2712                            Jenny
# 2834                            Jenny
# 2287                            Jenny
# 2977                           Jeremy
# 2379                           Jeremy
# 2420                           Jeremy
# 2526                           Jeremy
# 1667                           Jeremy
# 3083                           Jeroen
# 2953                           Jeroen
# 2389                           Jeroen
# 3132                           Jeroen
# 1349                           Jeroen
# 2189                            Jerry
# 1791                            Jerry
# 675                             Jerry
# 1611                            Jerry
# 960                             Jerry
# 2531                          Jessica
# 2509                          Jessica
# 2508                          Jessica
# 245                           Jessica
# 2402                          Jessica
# 3006                            Jesus
# 2329                            Jesus
# 98                              Jesus
# 2691                            Jesus
# 2695                            Jesus
# 1862                            Jesús
# 2197                            Jesús
# 117                             Jesús
# 1043                            Jesús
# 968                               Jim
# 2997                              Jim
# 928                               Jim
# 1476                              Jim
# 2936                              Jim
# 2048                               Jo
# 2608                               Jo
# 3026                               Jo
# 2062                               Jo
# 2503                               Jo
# 646                               Joe
# 1433                              Joe
# 620                               Joe
# 1045                              Joe
# 1924                              Joe
# 800                             Johan
# 2223                            Johan
# 3036                            Johan
# 5                                John
# 286                              John
# 230                              John
# 179                              John
# 4                                John
# 2932                           Johnny
# 426                            Johnny
# 2724                           Johnny
# 1813                           Johnny
# 2227                           Johnny
# 2966                              Jon
# 3022                              Jon
# 2183                              Jon
# 1011                              Jon
# 3051                              Jon
# 2803                            Jonas
# 2038                            Jonas
# 1979                            Jonas
# 2224                            Jonas
# 3034                            Jonas
# 2359                         Jonathan
# 2444                         Jonathan
# 935                          Jonathan
# 2255                         Jonathan
# 1129                         Jonathan
# 2203                           Jordan
# 2300                           Jordan
# 190                            Jordan
# 2092                           Jordan
# 684                            Jordan
# 1777                            Jordi
# 1360                            Jordi
# 1794                            Jordi
# 2617                            Jordi
# 2040                            Jordi
# 329                             Jorge
# 853                             Jorge
# 260                             Jorge
# 1106                            Jorge
# 712                             Jorge
# 971                              Jose
# 579                              Jose
# 1599                             Jose
# 999                              Jose
# 1745                             Jose
# 3109                        Jose Luis
# 1873                        Jose Luis
# 2930                        Jose Luis
# 3131                        Jose Luis
# 3060                        Jose Luis
# 268                            Joseph
# 1206                           Joseph
# 542                            Joseph
# 1191                           Joseph
# 368                            Joseph
# 1807                             Josh
# 1708                             Josh
# 905                              Josh
# 1217                             Josh
# 1772                             Josh
# 476                            Joshua
# 1875                           Joshua
# 2734                           Joshua
# 85                             Joshua
# 2906                           Joshua
# 3108                             José
# 2853                             José
# 883                              Juan
# 183                              Juan
# 1398                             Juan
# 949                              Juan
# 1170                             Juan
# 2786                      Juan Carlos
# 2818                      Juan Carlos
# 200                       Juan Carlos
# 685                       Juan Carlos
# 2621                      Juan Carlos
# 1689                            Julia
# 2432                            Julia
# 2988                            Julia
# 2998                            Julia
# 2073                            Julia
# 2652                           Julian
# 2785                           Julian
# 2205                           Julian
# 2735                           Julian
# 2194                           Julian
# 654                             Julie
# 1775                            Julie
# 1434                            Julie
# 1555                            Julie
# 819                             Julie
# 2174                           Julien
# 2339                           Julien
# 1203                           Julien
# 2463                           Julien
# 1245                           Julien
# 3133                            Julio
# 1361                            Julio
# 1249                            Julio
# 2134                            Julio
# ...
# 1946  {'was_impossible': False}
# 125   {'was_impossible': False}
# 1524  {'was_impossible': False}
# 2221  {'was_impossible': False}
# 2458  {'was_impossible': False}
# 810   {'was_impossible': False}
# 3069  {'was_impossible': False}
# 2095  {'was_impossible': False}
# 2721  {'was_impossible': False}
# 2624  {'was_impossible': False}
# 1065  {'was_impossible': False}
# 1685  {'was_impossible': False}
# 1625  {'was_impossible': False}
# 349   {'was_impossible': False}
# 502   {'was_impossible': False}
# 791   {'was_impossible': False}
# 1966  {'was_impossible': False}
# 3019  {'was_impossible': False}
# 1329  {'was_impossible': False}
# 1125  {'was_impossible': False}
# 2744  {'was_impossible': False}
# 2651  {'was_impossible': False}
# 1490  {'was_impossible': False}
# 2766  {'was_impossible': False}
# 2201  {'was_impossible': False}
# 1918  {'was_impossible': False}
# 930   {'was_impossible': False}
# 1744  {'was_impossible': False}
# 1193  {'was_impossible': False}
# 1153  {'was_impossible': False}
# 1653  {'was_impossible': False}
# 601   {'was_impossible': False}
# 2888  {'was_impossible': False}
# 1198  {'was_impossible': False}
# 1425  {'was_impossible': False}
# 216   {'was_impossible': False}
# 2024  {'was_impossible': False}
# 2374  {'was_impossible': False}
# 2613  {'was_impossible': False}
# 354   {'was_impossible': False}
# 2581  {'was_impossible': False}
# 1879  {'was_impossible': False}
# 1315  {'was_impossible': False}
# 2462  {'was_impossible': False}
# 2801  {'was_impossible': False}
# 932   {'was_impossible': False}
# 1683  {'was_impossible': False}
# 2635  {'was_impossible': False}
# 1748  {'was_impossible': False}
# 224   {'was_impossible': False}
# 1727  {'was_impossible': False}
# 939   {'was_impossible': False}
# 2151  {'was_impossible': False}
# 2874  {'was_impossible': False}
# 2666  {'was_impossible': False}
# 2296  {'was_impossible': False}
# 1319  {'was_impossible': False}
# 2907  {'was_impossible': False}
# 1149  {'was_impossible': False}
# 505   {'was_impossible': False}
# 2716  {'was_impossible': False}
# 961   {'was_impossible': False}
# 1812  {'was_impossible': False}
# 101   {'was_impossible': False}
# 46    {'was_impossible': False}
# 2304  {'was_impossible': False}
# 668   {'was_impossible': False}
# 1681  {'was_impossible': False}
# 2632  {'was_impossible': False}
# 2455  {'was_impossible': False}
# 2945  {'was_impossible': False}
# 2942  {'was_impossible': False}
# 2961  {'was_impossible': False}
# 3074  {'was_impossible': False}
# 2384  {'was_impossible': False}
# 1633  {'was_impossible': False}
# 2748  {'was_impossible': False}
# 1785  {'was_impossible': False}
# 331   {'was_impossible': False}
# 1440  {'was_impossible': False}
# 717   {'was_impossible': False}
# 1297  {'was_impossible': False}
# 68    {'was_impossible': False}
# 1332  {'was_impossible': False}
# 1852  {'was_impossible': False}
# 900   {'was_impossible': False}
# 1084  {'was_impossible': False}
# 2245  {'was_impossible': False}
# 106   {'was_impossible': False}
# 2066  {'was_impossible': False}
# 1464  {'was_impossible': False}
# 3064  {'was_impossible': False}
# 1515  {'was_impossible': False}
# 521   {'was_impossible': False}
# 1642  {'was_impossible': False}
# 815   {'was_impossible': False}
# 1213  {'was_impossible': False}
# 1655  {'was_impossible': False}
# 320   {'was_impossible': False}
# 2285  {'was_impossible': False}
# 891   {'was_impossible': False}
# 2243  {'was_impossible': False}
# 2100  {'was_impossible': False}
# 1179  {'was_impossible': False}
# 1200  {'was_impossible': False}
# 985   {'was_impossible': False}
# 1105  {'was_impossible': False}
# 1713  {'was_impossible': False}
# 1028  {'was_impossible': False}
# 1834  {'was_impossible': False}
# 857   {'was_impossible': False}
# 920   {'was_impossible': False}
# 2310  {'was_impossible': False}
# 1470  {'was_impossible': False}
# 2047  {'was_impossible': False}
# 2759  {'was_impossible': False}
# 1869  {'was_impossible': False}
# 2838  {'was_impossible': False}
# 2644  {'was_impossible': False}
# 794   {'was_impossible': False}
# 2163  {'was_impossible': False}
# 2902  {'was_impossible': False}
# 355   {'was_impossible': False}
# 2354  {'was_impossible': False}
# 3076  {'was_impossible': False}
# 2172  {'was_impossible': False}
# 1157  {'was_impossible': False}
# 1042  {'was_impossible': False}
# 661   {'was_impossible': False}
# 582   {'was_impossible': False}
# 758   {'was_impossible': False}
# 197   {'was_impossible': False}
# 463   {'was_impossible': False}
# 2657  {'was_impossible': False}
# 2467  {'was_impossible': False}
# 1196  {'was_impossible': False}
# 2164  {'was_impossible': False}
# 2777  {'was_impossible': False}
# 252   {'was_impossible': False}
# 2954  {'was_impossible': False}
# 2837  {'was_impossible': False}
# 2983  {'was_impossible': False}
# 2594  {'was_impossible': False}
# 1629  {'was_impossible': False}
# 2303  {'was_impossible': False}
# 1983  {'was_impossible': False}
# 1649  {'was_impossible': False}
# 232   {'was_impossible': False}
# 2051  {'was_impossible': False}
# 1920  {'was_impossible': False}
# 172   {'was_impossible': False}
# 1854  {'was_impossible': False}
# 2485  {'was_impossible': False}
# 1800  {'was_impossible': False}
# 2471  {'was_impossible': False}
# 1072  {'was_impossible': False}
# 1078  {'was_impossible': False}
# 909   {'was_impossible': False}
# 963   {'was_impossible': False}
# 696   {'was_impossible': False}
# 2341  {'was_impossible': False}
# 353   {'was_impossible': False}
# 2944  {'was_impossible': False}
# 3033  {'was_impossible': False}
# 705   {'was_impossible': False}
# 296   {'was_impossible': False}
# 137   {'was_impossible': False}
# 558   {'was_impossible': False}
# 398   {'was_impossible': False}
# 284   {'was_impossible': False}
# 1905  {'was_impossible': False}
# 1168  {'was_impossible': False}
# 2431  {'was_impossible': False}
# 2253  {'was_impossible': False}
# 977   {'was_impossible': False}
# 422   {'was_impossible': False}
# 619   {'was_impossible': False}
# 801   {'was_impossible': False}
# 466   {'was_impossible': False}
# 571   {'was_impossible': False}
# 1022  {'was_impossible': False}
# 1576  {'was_impossible': False}
# 2098  {'was_impossible': False}
# 1029  {'was_impossible': False}
# 442   {'was_impossible': False}
# 1763  {'was_impossible': False}
# 1207  {'was_impossible': False}
# 1132  {'was_impossible': False}
# 1580  {'was_impossible': False}
# 1251  {'was_impossible': False}
# 2318  {'was_impossible': False}
# 2177  {'was_impossible': False}
# 2415  {'was_impossible': False}
# 1024  {'was_impossible': False}
# 2915  {'was_impossible': False}
# 849   {'was_impossible': False}
# 841   {'was_impossible': False}
# 623   {'was_impossible': False}
# 160   {'was_impossible': False}
# 191   {'was_impossible': False}
# 69    {'was_impossible': False}
# 665   {'was_impossible': False}
# 382   {'was_impossible': False}
# 271   {'was_impossible': False}
# 267   {'was_impossible': False}
# 1304  {'was_impossible': False}
# 1300  {'was_impossible': False}
# 341   {'was_impossible': False}
# 745   {'was_impossible': False}
# 1218  {'was_impossible': False}
# 1467  {'was_impossible': False}
# 425   {'was_impossible': False}
# 506   {'was_impossible': False}
# 584   {'was_impossible': False}
# 1374  {'was_impossible': False}
# 437   {'was_impossible': False}
# 2226  {'was_impossible': False}
# 1202  {'was_impossible': False}
# 772   {'was_impossible': False}
# 1258  {'was_impossible': False}
# 2114  {'was_impossible': False}
# 2283  {'was_impossible': False}
# 1889  {'was_impossible': False}
# 541   {'was_impossible': False}
# 1451  {'was_impossible': False}
# 208   {'was_impossible': False}
# 1377  {'was_impossible': False}
# 1404  {'was_impossible': False}
# 474   {'was_impossible': False}
# 1450  {'was_impossible': False}
# 1414  {'was_impossible': False}
# 2202  {'was_impossible': False}
# 1991  {'was_impossible': False}
# 714   {'was_impossible': False}
# 2733  {'was_impossible': False}
# 2800  {'was_impossible': False}
# 2847  {'was_impossible': False}
# 2489  {'was_impossible': False}
# 2005  {'was_impossible': False}
# 2173  {'was_impossible': False}
# 1694  {'was_impossible': False}
# 434   {'was_impossible': False}
# 730   {'was_impossible': False}
# 1248  {'was_impossible': False}
# 460   {'was_impossible': False}
# 520   {'was_impossible': False}
# 1486  {'was_impossible': False}
# 984   {'was_impossible': False}
# 90    {'was_impossible': False}
# 1295  {'was_impossible': False}
# 1928  {'was_impossible': False}
# 1880  {'was_impossible': False}
# 1912  {'was_impossible': False}
# 1811  {'was_impossible': False}
# 1771  {'was_impossible': False}
# 1757  {'was_impossible': False}
# 532   {'was_impossible': False}
# 2052  {'was_impossible': False}
# 2118  {'was_impossible': False}
# 2311  {'was_impossible': False}
# 1007  {'was_impossible': False}
# 459   {'was_impossible': False}
# 590   {'was_impossible': False}
# 171   {'was_impossible': False}
# 736   {'was_impossible': False}
# 259   {'was_impossible': False}
# 1014  {'was_impossible': False}
# 1695  {'was_impossible': False}
# 1566  {'was_impossible': False}
# 1870  {'was_impossible': False}
# 2582  {'was_impossible': False}
# 1384  {'was_impossible': False}
# 1231  {'was_impossible': False}
# 1107  {'was_impossible': False}
# 2667  {'was_impossible': False}
# 1390  {'was_impossible': False}
# 307   {'was_impossible': False}
# 63    {'was_impossible': False}
# 275   {'was_impossible': False}
# 378   {'was_impossible': False}
# 423   {'was_impossible': False}
# 1513  {'was_impossible': False}
# 1608  {'was_impossible': False}
# 1537  {'was_impossible': False}
# 1688  {'was_impossible': False}
# 432   {'was_impossible': False}
# 217   {'was_impossible': False}
# 274   {'was_impossible': False}
# 458   {'was_impossible': False}
# 729   {'was_impossible': False}
# 834   {'was_impossible': False}
# 746   {'was_impossible': False}
# 569   {'was_impossible': False}
# 1175  {'was_impossible': False}
# 2607  {'was_impossible': False}
# 148   {'was_impossible': False}
# 461   {'was_impossible': False}
# 537   {'was_impossible': False}
# 150   {'was_impossible': False}
# 110   {'was_impossible': False}
# 624   {'was_impossible': False}
# 481   {'was_impossible': False}
# 348   {'was_impossible': False}
# 1140  {'was_impossible': False}
# 1049  {'was_impossible': False}
# 244   {'was_impossible': False}
# 1178  {'was_impossible': False}
# 832   {'was_impossible': False}
# 785   {'was_impossible': False}
# 1205  {'was_impossible': False}
# 141   {'was_impossible': False}
# 1162  {'was_impossible': False}
# 1313  {'was_impossible': False}
# 448   {'was_impossible': False}
# 1595  {'was_impossible': False}
# 490   {'was_impossible': False}
# 430   {'was_impossible': False}
# 578   {'was_impossible': False}
# 487   {'was_impossible': False}
# 1288  {'was_impossible': False}
# 966   {'was_impossible': False}
# 602   {'was_impossible': False}
# 30    {'was_impossible': False}
# 328   {'was_impossible': False}
# 470   {'was_impossible': False}
# 1163  {'was_impossible': False}
# 1052  {'was_impossible': False}
# 113   {'was_impossible': False}
# 686   {'was_impossible': False}
# 1172  {'was_impossible': False}
# 692   {'was_impossible': False}
# 864   {'was_impossible': False}
# 1041  {'was_impossible': False}
# 925   {'was_impossible': False}
# 409   {'was_impossible': False}
# 1354  {'was_impossible': False}
# 522   {'was_impossible': False}
# 1283  {'was_impossible': False}
# 625   {'was_impossible': False}
# 1269  {'was_impossible': False}
# 1002  {'was_impossible': False}
# 1023  {'was_impossible': False}
# 1917  {'was_impossible': False}
# 806   {'was_impossible': False}
# 1899  {'was_impossible': False}
# 350   {'was_impossible': False}
# 1400  {'was_impossible': False}
# 1916  {'was_impossible': False}
# 529   {'was_impossible': False}
# 1160  {'was_impossible': False}
# 1063  {'was_impossible': False}
# 1443  {'was_impossible': False}
# 953   {'was_impossible': False}
# 632   {'was_impossible': False}
# 855   {'was_impossible': False}
# 1368  {'was_impossible': False}
# 709   {'was_impossible': False}
# 324   {'was_impossible': False}
# 902   {'was_impossible': False}
# 1046  {'was_impossible': False}
# 1701  {'was_impossible': False}
# 1494  {'was_impossible': False}
# 2235  {'was_impossible': False}
# 1488  {'was_impossible': False}
# 2158  {'was_impossible': False}
# 1285  {'was_impossible': False}
# 1004  {'was_impossible': False}
# 1572  {'was_impossible': False}
# 1652  {'was_impossible': False}
# 1565  {'was_impossible': False}
# 973   {'was_impossible': False}
# 988   {'was_impossible': False}
# 264   {'was_impossible': False}
# 688   {'was_impossible': False}
# 1027  {'was_impossible': False}
# 50    {'was_impossible': False}
# 1018  {'was_impossible': False}
# 1068  {'was_impossible': False}
# 1343  {'was_impossible': False}
# 1352  {'was_impossible': False}
# 1015  {'was_impossible': False}
# 808   {'was_impossible': False}
# 49    {'was_impossible': False}
# 1135  {'was_impossible': False}
# 124   {'was_impossible': False}
# 2250  {'was_impossible': False}
# 2464  {'was_impossible': False}
# 1276  {'was_impossible': False}
# 1796  {'was_impossible': False}
# 2586  {'was_impossible': False}
# 1171  {'was_impossible': False}
# 1458  {'was_impossible': False}
# 1005  {'was_impossible': False}
# 1279  {'was_impossible': False}
# 862   {'was_impossible': False}
# 312   {'was_impossible': False}
# 2682  {'was_impossible': False}
# 2701  {'was_impossible': False}
# 1347  {'was_impossible': False}
# 2625  {'was_impossible': False}
# 597   {'was_impossible': False}
# 784   {'was_impossible': False}
# 1165  {'was_impossible': False}
# 548   {'was_impossible': False}
# 1323  {'was_impossible': False}
# 478   {'was_impossible': False}
# 1047  {'was_impossible': False}
# 1839  {'was_impossible': False}
# 2356  {'was_impossible': False}
# 997   {'was_impossible': False}
# 669   {'was_impossible': False}
# 509   {'was_impossible': False}
# 91    {'was_impossible': False}
# 201   {'was_impossible': False}
# 147   {'was_impossible': False}
# 603   {'was_impossible': False}
# 335   {'was_impossible': False}
# 492   {'was_impossible': False}
# 471   {'was_impossible': False}
# 405   {'was_impossible': False}
# 2204  {'was_impossible': False}
# 2064  {'was_impossible': False}
# 247   {'was_impossible': False}
# 236   {'was_impossible': False}
# 2278  {'was_impossible': False}
# 798   {'was_impossible': False}
# 789   {'was_impossible': False}
# 1060  {'was_impossible': False}
# 1579  {'was_impossible': False}
# 257   {'was_impossible': False}
# 1699  {'was_impossible': False}
# 671   {'was_impossible': False}
# 1634  {'was_impossible': False}
# 1890  {'was_impossible': False}
# 2886  {'was_impossible': False}
# 1054  {'was_impossible': False}
# 1474  {'was_impossible': False}
# 840   {'was_impossible': False}
# 1540  {'was_impossible': False}
# 2259  {'was_impossible': False}
# 1061  {'was_impossible': False}
# 641   {'was_impossible': False}
# 1314  {'was_impossible': False}
# 926   {'was_impossible': False}
# 1413  {'was_impossible': False}
# 278   {'was_impossible': False}
# 294   {'was_impossible': False}
# 373   {'was_impossible': False}
# 114   {'was_impossible': False}
# 74    {'was_impossible': False}
# 1715  {'was_impossible': False}
# 1842  {'was_impossible': False}
# 1549  {'was_impossible': False}
# 436   {'was_impossible': False}
# 583   {'was_impossible': False}
# 402   {'was_impossible': False}
# 1088  {'was_impossible': False}
# 66    {'was_impossible': False}
# 221   {'was_impossible': False}
# 1833  {'was_impossible': False}
# 396   {'was_impossible': False}
# 728   {'was_impossible': False}
# 672   {'was_impossible': False}
# 612   {'was_impossible': False}
# 1194  {'was_impossible': False}
# 1981  {'was_impossible': False}
# 1197  {'was_impossible': False}
# 1628  {'was_impossible': False}
# 518   {'was_impossible': False}
# 1739  {'was_impossible': False}

# %% [markdown]
# ## 9. Try other techniques (Example: cross validation) to get better results. [3 Marks]

# %%
from surprise import NMF
from surprise import KNNBaseline
from surprise import KNNBasic
from surprise import KNNWithZScore
from surprise import BaselineOnly
from surprise import CoClustering
benchmark = []
# Iterate over different algorithms
for algorithm in [SVD(), KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True}),
                  NMF(), KNNBaseline(), KNNBasic(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
    # Perform cross validation
    results = cross_validate(algorithm, data, measures=['RMSE'], cv=5, verbose=False)
    
    # Document Results
    tmp_res = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp_res = tmp_res.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp_res)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
#                test_rmse  fit_time  test_time
# Algorithm
# BaselineOnly    2.586091  0.247751   0.080693
# SVD             2.645955  5.159474   0.163024
# CoClustering    2.646058  2.054477   0.140885
# KNNBaseline     2.667041  0.640033   3.101351
# KNNBasic        2.673150  0.425397   2.750316
# KNNWithZScore   2.676785  0.538523   2.952492
# KNNWithMeans    2.736032  0.838428   2.900748
# NMF             3.205908  5.398080   0.132282

# %% [markdown]
# ### Observation
# 1. Best prediction algorithm with lowest RMSE is BaselineOnly followed by SVD.
# 2. BaselineOnly algoritm also take lowest time to compute
# 3. Needless to say RMSE of 2.5 is still very high
# 4. However if we will round the recommendation to nearest integer the error decreases.
# 5. Skipped item-item CF as it took very long time to compute earlier.

# %% [markdown]
# ## 10. In what business scenario you should use popularity based Recommendation Systems ? [2 Marks]
#
# 1. Popularity based Recommended system works on trends i.e. what is in demand.
# 2. We will use it in scenarios where we have (cold start problems) i.e. new user without any history so we can recommend him most popular items on site.
# 3. Not having enough information on the likes and dislikes at an user level can be overcome by this system even on Day1
# 4. Items that have become popular in short amount of time should also be recommended by Popularity based system e.g. top selling books this month.
#
# e.g.
# 1. Trending Videos for new comer on site
# 2. Most popular news when user perfrences are not known
# 3. Most sold products on e-commerce sites for a new user

# %% [markdown]
# ## 11. In what business scenario you should use CF based Recommendation Systems ? [2 Marks
#
# 1. Collaborative filtering is a personalized recommendation system that identifies the similarities between users (based on their taste ) to serve relevant product recommendations.
# 2. E.g. Netflix movies i.e. if your set of prefences matches to someother users( lets call them digital clones/neighbours) who have watched same movies and given similar ratings. Then on next login the user will display movies watched by your digital clones/neighbours that you have not yet seen.
# 3. If business already has good amount of data about user's historical choices then CF based recommendation systems should be used. It will help in customer retention and will also make customer purchase faster, since the discovery time of needs get reduced.

# %% [markdown]
# ## 12. What other possible methods can you think of which can further improve the recommendation for different users ?
#
# 1. Use hybrid approach between differnt recommendations to cover for different perspectives e.g. similar tastes, newness, mood changes etc.
# 2. Bundling should also be suggested using Apriori basket method for recommendation
# 3. Demographics based recommendation system i.e. Trending near you can also be used for e.g. if you have to vist a nearby hotel etc.
# 4. Feature based recommendation system which focuses on key features to recommend a product.
# 5. Knowledge / Certification based recommendation system e.g. while selling re-used cars the most important thing is if a SME can say that it has passed all the certification tests
